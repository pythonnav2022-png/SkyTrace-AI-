# %%
import pandas as pd
import ee
ee.Initialize(project="skytrace-ai")
# 1. قائمة الغازات اللي غانراقبو (Les Collections Sentinel-5P)
gaz_collections = {
    'NO2': 'COPERNICUS/S5P/OFFL/L3_NO2',
    'CO': 'COPERNICUS/S5P/OFFL/L3_CO',
    'CH4': 'COPERNICUS/S5P/OFFL/L3_CH4',
    'SO2': 'COPERNICUS/S5P/OFFL/L3_SO2'
}

# 2. الإحداثيات (اللي جابت صاحبتك)
zones = {
    'Jorf Lasfar (OCP)': [-8.638, 33.105],
    'El Jadida': [-8.500, 33.231],
    'Safi Industrial': [-9.237, 32.299],
    'Mohammedia Port': [-7.383, 33.686],
    'Casablanca Industrial Zone': [-7.603, 33.589],
    'Nouaceur / Midparc': [-7.589, 33.367],
    'Berrechid Industrial Zone': [-7.587, 33.265],
    'Settat Industrial Zone': [-7.620, 33.000],
    'Kenitra Industrial Zone': [-6.578, 34.261],
    'Tangier Med': [-5.503, 35.893],
    'Tangier Automotive City': [-5.912, 35.726],
    'Tetouan Industrial Zone': [-5.362, 35.578],
    'Nador West Med': [-2.928, 35.169],
    'Oujda Industrial Zone': [-1.907, 34.682],
    'Fes Industrial Zone': [-5.003, 34.033],
    'Meknes Industrial Zone': [-5.547, 33.894],
    'Khouribga': [-6.906, 32.881],
    'Beni Mellal Industrial Zone': [-6.349, 32.337],
    'Marrakech Industrial Zone': [-8.008, 31.630],
    'Agadir Industrial Zone': [-9.598, 30.427],
    'Laayoune Industrial Zone': [-13.203, 27.153],
    'Dakhla Industrial Zone': [-15.957, 23.684]
}
results = []

# 3. Boucle bach n-jbdou kolla gaz l-kolla blassa
for gaz_name, collection_path in gaz_collections.items():
    # جلب الداتا ديال الغاز المعين
    data = ee.ImageCollection(collection_path) \
             .filterDate('2026-03-01', '2026-03-31') \
             .mean()
    
    # تحديد السمية ديال الـ Band (كتختالف من غاز لآخر)
    band_name = data.bandNames().get(0) 
    
    for zone_name, coords in zones.items():
        point = ee.Geometry.Point(coords)
        
        # استخراج القيمة
        val = data.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=point,
            scale=1000
        ).get(band_name).getInfo()
        
        results.append({
            'Zone': zone_name,
            'Gaz': gaz_name,
            'Concentration': val
        })

# 4. تحويل لجدول شامل (Multi-Gas Table)
df_final = pd.DataFrame(results)
# Pivot table bach i-ban nqi (Zones en lignes, Gaz en colonnes)
df_pivot = df_final.pivot(index='Zone', columns='Gaz', values='Concentration')

print(df_pivot)
# Out:
# Gaz                                  CH4        CO       NO2       SO2
# Zone
# Agadir Industrial Zone       1890.936213  0.030056  0.000073  0.000128
# Beni Mellal Industrial Zone  1876.308772  0.027456  0.000065  0.000057
# Berrechid Industrial Zone    1910.916839  0.029078  0.000090  0.000129
# Casablanca Industrial Zone   1917.184303  0.030604  0.000105 -0.000071
# Dakhla Industrial Zone       1922.302780  0.029439  0.000054  0.000119
# El Jadida                    1911.968955  0.029887  0.000071  0.000073
# Fes Industrial Zone          1905.491708  0.028812  0.000071 -0.000014
# Jorf Lasfar (OCP)            1900.448280  0.030597  0.000085  0.000322
# Kenitra Industrial Zone      1924.239628  0.030677  0.000077 -0.000008
# Khouribga                    1900.264973  0.025901  0.000066  0.000179
# Laayoune Industrial Zone     1932.191372  0.029010  0.000059  0.000012
# Marrakech Industrial Zone    1900.024161  0.029817  0.000079 -0.000011
# Meknes Industrial Zone       1910.043950  0.027732  0.000074 -0.000102
# Mohammedia Port              1910.410729  0.029879  0.000085 -0.000104
# Nador West Med               1882.851510  0.030464  0.000065 -0.000033
# Nouaceur / Midparc           1912.366588  0.029653  0.000099  0.000108
# Oujda Industrial Zone        1916.158539  0.028850  0.000064 -0.000006
# Safi Industrial              1893.322752  0.029797  0.000071  0.000288
# Settat Industrial Zone       1892.598746  0.028404  0.000074  0.000182
# Tangier Automotive City      1932.140612  0.030172  0.000084  0.000050
# Tangier Med                  1908.085193  0.030092  0.000090  0.000272
# Tetouan Industrial Zone      1908.177850  0.030066  0.000070  0.000016

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Lenovo\anaconda31\python.exe

# %%
import sys
# !{sys.executable} -m pip install earthengine-api
# Out:
# Collecting earthengine-api
#   Using cached earthengine_api-1.7.21-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-cloud-storage (from earthengine-api)
#   Using cached google_cloud_storage-3.10.1-py3-none-any.whl.metadata (15 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api)
#   Downloading google_api_python_client-2.194.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-auth>=1.4.1 (from earthengine-api)
#   Downloading google_auth-2.49.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api)
#   Using cached google_auth_httplib2-0.3.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api)
#   Using cached httplib2-0.31.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda31\lib\site-packages (from earthengine-api) (2.32.5)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\lenovo\anaconda31\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.5)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api)
#   Downloading google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api)
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Using cached googleapis_common_protos-1.74.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\lenovo\anaconda31\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Using cached proto_plus-1.27.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda31\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\lenovo\anaconda31\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (46.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda31\lib\site-packages (from requests->earthengine-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda31\lib\site-packages (from requests->earthengine-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda31\lib\site-packages (from requests->earthengine-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda31\lib\site-packages (from requests->earthengine-api) (2025.11.12)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\lenovo\anaconda31\lib\site-packages (from cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda31\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\lenovo\anaconda31\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->earthengine-api)
#   Using cached google_cloud_core-2.5.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->earthengine-api)
#   Using cached google_resumable_media-2.8.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->earthengine-api)
#   Downloading google_crc32c-1.8.0-cp313-cp313-win_amd64.whl.metadata (1.8 kB)
# Using cached earthengine_api-1.7.21-py3-none-any.whl (479 kB)
# Using cached httplib2-0.31.2-py3-none-any.whl (91 kB)
# Downloading google_api_python_client-2.194.0-py3-none-any.whl (15.0 MB)
#    ---------------------------------------- 0.0/15.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.0 MB ? eta -:--:--
#    ------------- -------------------------- 5.0/15.0 MB 23.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.7/15.0 MB 24.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.0 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.0 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.0 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.0/15.0 MB 11.5 MB/s  0:00:01
# Downloading google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Downloading google_auth-2.49.2-py3-none-any.whl (240 kB)
# Using cached google_auth_httplib2-0.3.1-py3-none-any.whl (9.5 kB)
# Using cached googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
# Using cached proto_plus-1.27.2-py3-none-any.whl (50 kB)
# Using cached uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Using cached google_cloud_storage-3.10.1-py3-none-any.whl (324 kB)
# Using cached google_cloud_core-2.5.1-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp313-cp313-win_amd64.whl (34 kB)
# Using cached google_resumable_media-2.8.2-py3-none-any.whl (81 kB)
# Installing collected packages: uritemplate, proto-plus, httplib2, googleapis-common-protos, google-crc32c, google-resumable-media, google-auth, google-auth-httplib2, google-api-core, google-cloud-core, google-api-python-client, google-cloud-storage, earthengine-api
#
#    ----------------------------------------  0/13 [uritemplate]
#    --- ------------------------------------  1/13 [proto-plus]
#    --- ------------------------------------  1/13 [proto-plus]
#    --- ------------------------------------  1/13 [proto-plus]
#    --- ------------------------------------  1/13 [proto-plus]
#    --- ------------------------------------  1/13 [proto-plus]
#    ------ ---------------------------------  2/13 [httplib2]
#    ------ ---------------------------------  2/13 [httplib2]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    --------- ------------------------------  3/13 [googleapis-common-protos]
#    ------------ ---------------------------  4/13 [google-crc32c]
#    --------------- ------------------------  5/13 [google-resumable-media]
#    --------------- ------------------------  5/13 [google-resumable-media]
#    --------------- ------------------------  5/13 [google-resumable-media]
#    --------------- ------------------------  5/13 [google-resumable-media]
#    --------------- ------------------------  5/13 [google-resumable-media]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    ------------------ ---------------------  6/13 [google-auth]
#    --------------------- ------------------  7/13 [google-auth-httplib2]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    ------------------------ ---------------  8/13 [google-api-core]
#    --------------------------- ------------  9/13 [google-cloud-core]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    ------------------------------ --------- 10/13 [google-api-python-client]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    --------------------------------- ------ 11/13 [google-cloud-storage]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ------------------------------------ --- 12/13 [earthengine-api]
#    ---------------------------------------- 13/13 [earthengine-api]
#
# Successfully installed earthengine-api-1.7.21 google-api-core-2.30.3 google-api-python-client-2.194.0 google-auth-2.49.2 google-auth-httplib2-0.3.1 google-cloud-core-2.5.1 google-cloud-storage-3.10.1 google-crc32c-1.8.0 google-resumable-media-2.8.2 googleapis-common-protos-1.74.0 httplib2-0.31.2 proto-plus-1.27.2 uritemplate-4.2.0

# %%
import ee
print("ee import OK")
# Out:
# ee import OK

# %%
ee.Initialize(project="skytrace-ai")
print("GEE connecté !")
# Out:
# GEE connecté !
